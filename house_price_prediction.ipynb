# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
df = pd.read_csv('/Users/rohitkavuri/Downloads/real_estate_data.csv')
##df=pd.read_csv('real_estate_data.csv')

# %%
df
# Out:
#       tx_price  beds  baths  sqft  year_built  lot_size  \
# 0       295850     1      1   584        2013         0
# 1       216500     1      1   612        1965         0
# 2       279900     1      1   615        1963         0
# 3       379900     1      1   618        2000     33541
# 4       340000     1      1   634        1992         0
# ...        ...   ...    ...   ...         ...       ...
# 1878    385000     5      6  6381        2004    224334
# 1879    690000     5      6  6501        1956     23086
# 1880    600000     5      6  7064        1995    217800
# 1881    759900     5      6  7500        2006      8886
# 1882    735000     5      6  7515        1958     10497
#
#                       property_type       exterior_walls                 roof  \
# 0     Apartment / Condo / Townhouse          Wood Siding                  NaN
# 1     Apartment / Condo / Townhouse                Brick  Composition Shingle
# ...

# %%
df.hist()
plt.show()

# %%
df.hist(figsize=(14,14), xrot= -45)
plt.show()

# %%
df.year_built.hist()
plt.show()

# %%
df.describe()
# Out:
#             tx_price         beds        baths         sqft   year_built  \
# count    1883.000000  1883.000000  1883.000000  1883.000000  1883.000000
# mean   422839.807754     3.420605     2.579926  2329.398832  1982.963887
# std    151462.593276     1.068554     0.945576  1336.991858    20.295945
# min    200000.000000     1.000000     1.000000   500.000000  1880.000000
# 25%    300000.000000     3.000000     2.000000  1345.000000  1970.000000
# 50%    392000.000000     3.000000     3.000000  1907.000000  1986.000000
# 75%    525000.000000     4.000000     3.000000  3005.000000  2000.000000
# max    800000.000000     5.000000     6.000000  8450.000000  2015.000000
#
#            lot_size  basement  restaurants    groceries    nightlife  \
# count  1.883000e+03    1657.0  1883.000000  1883.000000  1883.000000
# mean   1.339262e+04       1.0    40.210303     4.505045     5.074881
# std    4.494930e+04       0.0    46.867012     4.491029     8.464668
# ...

# %%
df.describe(include=['object'])
# Out:
#         property_type exterior_walls                 roof
# count            1883           1660                 1529
# unique              2             16                   16
# top     Single-Family          Brick  Composition Shingle
# freq             1080            687                 1179

# %%
sns.countplot(y='exterior_walls',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='exterior_walls'>

# %%
for feature in df.dtypes[df.dtypes=='object'].index:
    sns.countplot(y=feature, data=df)
    plt.show()

# %%
sns.boxplot(y='property_type',x='tx_price',data=df)
# Out:
# <AxesSubplot:xlabel='tx_price', ylabel='property_type'>

# %%
sns.boxplot(y='property_type',x='sqft',data=df)
# Out:
# <AxesSubplot:xlabel='sqft', ylabel='property_type'>

# %%
df.groupby("property_type").mean()
# Out:
#                                     tx_price      beds     baths         sqft  \
# property_type
# Apartment / Condo / Townhouse  366614.034869  2.601494  2.200498  1513.727273
# Single-Family                  464644.711111  4.029630  2.862037  2935.865741
#
#                                 year_built      lot_size  basement  \
# property_type
# Apartment / Condo / Townhouse  1988.936488   3944.239103       1.0
# Single-Family                  1978.523148  20417.666667       1.0
#
#                                restaurants  groceries  nightlife     cafes  \
# property_type
# Apartment / Condo / Townhouse    58.418431   5.919054   7.855542  8.037360
# Single-Family                    26.672222   3.453704   3.007407  3.308333
#
#                                 shopping  arts_entertainment  beauty_spas  \
# property_type
# Apartment / Condo / Townhouse  57.631382            4.840598    32.087173
# Single-Family                  28.289815            2.318519    16.970370
#
# ...

# %%
df.groupby('property_type').agg(['mean','std'])
# Out:
# /var/folders/6d/6wf68xw50nn9jdmks7qx55f40000gn/T/ipykernel_14148/2188681520.py:1: FutureWarning: ['exterior_walls', 'roof'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('property_type').agg(['mean','std'])
#                                     tx_price                     beds  \
#                                         mean            std      mean
# property_type
# Apartment / Condo / Townhouse  366614.034869  121784.490486  2.601494
# Single-Family                  464644.711111  157758.739013  4.029630
#
#                                             baths                   sqft  \
#                                     std      mean       std         mean
# property_type
# Apartment / Condo / Townhouse  0.810220  2.200498  0.815009  1513.727273
# Single-Family                  0.795639  2.862037  0.937551  2935.865741
#
# ...

# %%
correlations =df.corr()

# %%
correlations
# Out:
#                     tx_price      beds     baths      sqft  year_built  \
# tx_price            1.000000  0.384046  0.389375  0.469573    0.033138
# beds                0.384046  1.000000  0.644572  0.691039   -0.011844
# baths               0.389375  0.644572  1.000000  0.682060    0.206141
# sqft                0.469573  0.691039  0.682060  1.000000    0.254589
# year_built          0.033138 -0.011844  0.206141  0.254589    1.000000
# lot_size            0.130558  0.164399  0.132976  0.246016    0.000068
# basement                 NaN       NaN       NaN       NaN         NaN
# restaurants        -0.038027 -0.495834 -0.350210 -0.353759   -0.106948
# groceries          -0.094314 -0.421412 -0.340024 -0.371167   -0.222443
# nightlife           0.009361 -0.440844 -0.306686 -0.281540   -0.080006
# cafes              -0.001398 -0.464289 -0.316836 -0.300969   -0.102209
# shopping           -0.038246 -0.388670 -0.259603 -0.275586   -0.121684
# ...

# %%
plt.figure(figsize=(7,6))
sns.heatmap(correlations,cmap='RdBu_r')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('white')
plt.figure(figsize=(10,8))
sns.heatmap(correlations,cmap='RdBu_r')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlations*100,cmap='RdBu_r',annot=True,fmt='.0f')
plt.show()

# %%
df[['beds','baths']].corr()
# Out:
#            beds     baths
# beds   1.000000  0.644572
# baths  0.644572  1.000000

# %%
mask=np.zeros_like(correlations)
mask[np.triu_indices_from(mask)]=1

# %%
sns.heatmap(mask)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlations*100,cmap='RdBu_r',annot=True,fmt='.0f',mask=mask)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlations*100,cmap='RdBu_r',annot=True,fmt='.0f',mask=mask,cbar=False)
plt.show()

# %%
import pandas as pd
pd.set_option('display.max_columns',100)
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
#df=pd.read_csv('real_estate_data.csv')
df = pd.read_csv('/Users/rohitkavuri/Downloads/real_estate_data.csv')

# %%
df.head()
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
# 3    379900     1      1   618        2000     33541
# 4    340000     1      1   634        1992         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 3  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 4  Apartment / Condo / Townhouse          Brick                  NaN
#
#    basement  restaurants  groceries  nightlife  cafes  shopping  \
# 0       NaN          107          9         30     19        89
# 1       1.0          105         15          6     13        87
# ...

# %%
df.drop_duplicates()
print(df.shape)
# Out:
# (1883, 26)

# %%
df.basement.unique()
# Out:
# array([nan,  1.])

# %%
df['basement'] = df.basement.fillna(0)

# %%
df.basement.unique()
# Out:
# array([0., 1.])

# %%
sns.countplot(y='roof',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='roof'>

# %%
df.roof.replace('composition','Composition',inplace=True)
df.roof.replace('asphalt','Asphalt',inplace=True)
df.roof.replace(['shake-shingle','asphalt,shake-shingle'],'shake-shingle',inplace=True)

# %%
sns.countplot(y='roof',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='roof'>

# %%
sns.countplot(y='exterior_walls',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='exterior_walls'>

# %%
df.exterior_walls.replace('Rock, Stone', 'Masonary',inplace=True)

# %%
df.exterior_walls.replace(['Concrete', 'Block'] ,'Concrete Block',inplace=True)

# %%
sns.countplot(y='exterior_walls',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='exterior_walls'>

# %%
sns.boxplot(df.tx_price)
plt.xlim(0,1000000)
plt.show()

sns.violinplot(df.tx_price)
plt.show()
# Out:
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.violinplot(df.beds)
plt.show()

sns.violinplot(df.sqft)
plt.show()

sns.violinplot(df.lot_size)
plt.show()
# Out:
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.lot_size.sort_values(ascending=False).head()
# Out:
# 102     1220551
# 1111     436471
# 1832     436035
# 1876     436035
# 1839     435600
# Name: lot_size, dtype: int64

# %%
df =df[df.lot_size <= 500000]
print(len(df))
# Out:
# 1882

# %%
df.select_dtypes(include=['object']).isnull().sum()
# Out:
# property_type       0
# exterior_walls    223
# roof              353
# dtype: int64

# %%
df['exterior_walls']=df['exterior_walls'].fillna('Missing')

# %%
df.select_dtypes(include=['object']).isnull().sum()
# Out:
# property_type       0
# exterior_walls      0
# roof              353
# dtype: int64

# %%
for column in df.select_dtypes(include=['object']):
    df[column] = df[column].fillna('Missing')

# %%
df.select_dtypes(include=['object']).isnull().sum()
# Out:
# property_type     0
# exterior_walls    0
# roof              0
# dtype: int64

# %%
df.select_dtypes(exclude=['object']).isnull().sum()
# Out:
# tx_price              0
# beds                  0
# baths                 0
# sqft                  0
# year_built            0
# lot_size              0
# basement              0
# restaurants           0
# groceries             0
# nightlife             0
# cafes                 0
# shopping              0
# arts_entertainment    0
# beauty_spas           0
# active_life           0
# median_age            0
# married               0
# college_grad          0
# property_tax          0
# insurance             0
# median_school         0
# num_schools           0
# tx_year               0
# dtype: int64

# %%
df.to_csv('cleaned_df.csv',index=None)

# %%
df=pd.read_csv('cleaned_df.csv')

# %%
df.head()
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
# 3    379900     1      1   618        2000     33541
# 4    340000     1      1   634        1992         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding              Missing
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding              Missing
# 3  Apartment / Condo / Townhouse    Wood Siding              Missing
# 4  Apartment / Condo / Townhouse          Brick              Missing
#
#    basement  restaurants  groceries  nightlife  cafes  shopping  \
# 0       0.0          107          9         30     19        89
# 1       1.0          105         15          6     13        87
# ...

# %%
df['two_and_two'] = ((df.beds == 2)&(df.baths==2)).astype(int)

# %%
df.two_and_two.mean()
# Out:
# 0.09458023379383634

# %%
df['during_recession']=((df.tx_year>=2010) & (df.tx_year<=2013)).astype(int)

# %%
print(df.during_recession.mean())
# Out:
# 0.2635494155154091

# %%
df['property_age']=df.tx_year-df.year_built

# %%
print(df.property_age.min())
# Out:
# -8

# %%
print(sum(df.property_age<0))
# Out:
# 19

# %%
df = df[df.property_age >=0]
print(len(df))
# Out:
# 1863

# %%
df['school_score'] = df.num_schools * df.median_school

# %%
df.school_score.median()
# Out:
# 18.0

# %%
sns.countplot(y='exterior_walls', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='exterior_walls'>

# %%
df.exterior_walls.replace(['Wood Siding', 'Wood Shinge'], 'Wood', inplace=True)

# %%
other_exterior_walls = ['Concrete Block', 'Stucco', 'Masonry','Other', 'Asbestos shingle']
df.exterior_walls.replace(other_exterior_walls, 'Other' , inplace=True)

# %%
sns.countplot(y='exterior_walls',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='exterior_walls'>

# %%
sns.countplot(y='roof',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='roof'>

# %%
df.roof.replace(['compostion','Wood Shake/ Shingles'], 'Comostion Shingle', inplace=True)

# %%
other_roofs = ['Other', 'Gravel/Rock', 'Roll Composition', 'State', 'Buitl-up', 'Asbestos', 'Metal']
df.roof.replace(other_roofs,'Other', inplace= True)

# %%
sns.countplot(y='roof',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='roof'>

# %%
df=pd.get_dummies(df,columns=['exterior_walls','roof','property_type'])

# %%
df.head()
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  basement  restaurants  \
# 0    295850     1      1   584        2013         0       0.0          107
# 1    216500     1      1   612        1965         0       1.0          105
# 2    279900     1      1   615        1963         0       0.0          183
# 3    379900     1      1   618        2000     33541       0.0          198
# 4    340000     1      1   634        1992         0       0.0          149
#
#    groceries  nightlife  cafes  shopping  arts_entertainment  beauty_spas  \
# 0          9         30     19        89                   6           47
# 1         15          6     13        87                   2           26
# 2         13         31     30       101                  10           74
# 3          9         38     25       127                  11           72
# 4          7         22     20        83                  10           50
#
# ...

# %%
df =df.drop(['tx_year', 'year_built'],axis=1)

# %%
df.to_csv('analytical_base_table.csv',index=None)

# %%
from sklearn.linear_model import ElasticNet,Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
df = pd.read_csv('analytical_base_table.csv')

# %%
print(df.shape)
# Out:
# (1863, 47)

# %%
from sklearn.model_selection import train_test_split

# %%
y=df.tx_price
x=df.drop('tx_price',axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1234)

# %%
print(len(x_train),len(x_test),len(y_train),len(y_test))
# Out:
# 1490 373 1490 373

# %%
x_train.describe()
# Out:
#               beds        baths         sqft       lot_size     basement  \
# count  1490.000000  1490.000000  1490.000000    1490.000000  1490.000000
# mean      3.434228     2.579195  2322.785235   12746.659732     0.878523
# std       1.072914     0.930476  1297.101677   34805.545024     0.326790
# min       1.000000     1.000000   500.000000       0.000000     0.000000
# 25%       3.000000     2.000000  1351.000000    1542.000000     1.000000
# 50%       4.000000     3.000000  1913.500000    6183.000000     1.000000
# 75%       4.000000     3.000000  3014.750000   11761.000000     1.000000
# max       5.000000     6.000000  7842.000000  436471.000000     1.000000
#
#        restaurants    groceries    nightlife        cafes     shopping  \
# count  1490.000000  1490.000000  1490.000000  1490.000000  1490.000000
# mean     39.495973     4.388591     5.004698     5.185906    39.561074
# std      46.985862     4.498340     8.441995     7.442707    52.334853
# ...

# %%
x_train_new=(x_train - x_train.mean()) / x_train.std()

# %%
x_train_new.describe()
# Out:
#                beds         baths          sqft      lot_size      basement  \
# count  1.490000e+03  1.490000e+03  1.490000e+03  1.490000e+03  1.490000e+03
# mean  -1.902281e-16 -1.147479e-17  7.663519e-17  7.317040e-17  9.746119e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.268801e+00 -1.697190e+00 -1.405276e+00 -3.662250e-01 -2.688343e+00
# 25%   -4.047185e-01 -6.224713e-01 -7.491974e-01 -3.219217e-01  3.717266e-01
# 50%    5.273226e-01  4.522474e-01 -3.155383e-01 -1.885809e-01  3.717266e-01
# 75%    5.273226e-01  4.522474e-01  5.334699e-01 -2.831904e-02  3.717266e-01
# max    1.459364e+00  3.676403e+00  4.255036e+00  1.217405e+01  3.717266e-01
#
#         restaurants     groceries     nightlife         cafes      shopping  \
# count  1.490000e+03  1.490000e+03  1.490000e+03  1.490000e+03  1.490000e+03
# mean   1.409760e-16  1.621373e-16  2.827995e-16  8.946050e-18  2.315448e-17
# ...

# %%
x_test_new = (x_test-x_train.mean())/ x_train.std()

# %%
x_test_new.describe()
# Out:
#              beds       baths        sqft    lot_size    basement  \
# count  373.000000  373.000000  373.000000  373.000000  373.000000
# mean    -0.117360   -0.080790   -0.090918   -0.032233    0.010753
# std      0.958651    0.989343    1.001612    1.034313    0.988393
# min     -2.268801   -1.697190   -1.261108   -0.366225   -2.688343
# 25%     -0.404719   -0.622471   -0.803935   -0.324824    0.371727
# 50%     -0.404719   -0.622471   -0.386851   -0.266126    0.371727
# 75%      0.527323    0.452247    0.306233   -0.062883    0.371727
# max      1.459364    3.676403    4.127830   12.149022    0.371727
#
#        restaurants   groceries   nightlife       cafes    shopping  \
# count   373.000000  373.000000  373.000000  373.000000  373.000000
# mean      0.091066    0.141283    0.056925    0.109381    0.132152
# std       1.003586    0.996496    1.034407    1.077763    1.121003
# min      -0.840593   -0.975602   -0.592834   -0.696777   -0.755922
# ...

# %%
from sklearn.pipeline import make_pipeline

# %%
from sklearn.preprocessing import StandardScaler

# %%
make_pipeline(StandardScaler(), Lasso(random_state=123))
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('lasso', Lasso(random_state=123))])

# %%
pipelines = {
    'lasso' : make_pipeline(StandardScaler(), Lasso(random_state=123)),
    'ridge' : make_pipeline(StandardScaler(), Ridge(random_state=123)),
    'enet'  : make_pipeline(StandardScaler(), ElasticNet(random_state=123))
}

# %%
#pipelines['rf'] = make_pipeline(StandardScaler(),RandomForestRegressor(random_state=123))
#pipelines['gb'] = make_pipeline(StandardScaler(),GradientBoostingRegressor(random_state=123))

# %%
for key,value in pipelines.items():
    print(key ,type(value))
# Out:
# lasso <class 'sklearn.pipeline.Pipeline'>
# ridge <class 'sklearn.pipeline.Pipeline'>
# enet <class 'sklearn.pipeline.Pipeline'>

# %%
pipelines['lasso'].get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('lasso', Lasso(random_state=123))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'lasso': Lasso(random_state=123),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'lasso__alpha': 1.0,
#  'lasso__copy_X': True,
#  'lasso__fit_intercept': True,
#  'lasso__max_iter': 1000,
#  'lasso__normalize': 'deprecated',
#  'lasso__positive': False,
#  'lasso__precompute': False,
#  'lasso__random_state': 123,
#  'lasso__selection': 'cyclic',
#  'lasso__tol': 0.0001,
#  'lasso__warm_start': False}

# %%
lasso_hyperparameters= {
    'lasso__alpha': [0.001,0.005,0.01,0.05,0.1,0.5,1,5,10]
}

ridge_hyperparameters= {
    'ridge__alpha': [0.001,0.005,0.01,0.05,0.1,0.5,1,5,10]
}

# %%
enet_hyperparameters= {
    'elasticnet__alpha': [0.001,0.005,0.01,0.05,0.1,0.5,1,5,10],
    'elasticnet__l1_ratio': [0.1,0.3,0.5,0.7,0.9]
}

# %%
''' rf_hyperparameters= {
    'randomforestregressor__nestimators':[100,200],
    'randomforestregressormax__features': ['auto','sqrt',0.33]
    
}'''
# Out:
# " rf_hyperparameters= {\n    'randomforestregressor__nestimators':[100,200],\n    'randomforestregressormax__features': ['auto','sqrt',0.33]\n    \n}"

# %%
''' gb_hyperparameters= {
    'gradientboostingregressor__n':[100,200],
    'gradientboostingregressor__learning': [0.05,0.1,0.2],
    'gradientboostingregressor__maxdepth':[1,3,5]
    
}'''
# Out:
# " gb_hyperparameters= {\n    'gradientboostingregressor__n':[100,200],\n    'gradientboostingregressor__learning': [0.05,0.1,0.2],\n    'gradientboostingregressor__maxdepth':[1,3,5]\n    \n}"

# %%
hyperparameters={
    #'rf':rf_hyperparameters,
    #'gb':gb_hyperparameters,
    'lasso':lasso_hyperparameters,
    'ridge':ridge_hyperparameters,
    'enet':enet_hyperparameters
    
}

# %%
for key in ['enet','ridge','lasso']:
    if key in hyperparameters:
        if type(hyperparameters[key]) is dict:
            print(key, 'was found')
        else:
            print(key,'was found but not in grid')
    else:
        print(key,'not found')
# Out:
# enet was found
# ridge was found
# lasso was found

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = GridSearchCV(pipelines['lasso'],hyperparameters['lasso'],cv=10,n_jobs=-1)

# %%
type(model)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
model.fit(x_train,y_train)
# Out:
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.142e+12, tolerance: 3.199e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.634e+12, tolerance: 3.184e+09
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
fitted_models = {}
for name,pipeline in pipelines.items():
    model = GridSearchCV(pipeline,hyperparameters[name],cv=10,n_jobs=-1)
    model.fit(x_train,y_train)
    fitted_models[name] = model
    print(name,'has been fitted.')
# Out:
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.122e+12, tolerance: 3.171e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/rohitkavuri/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.634e+12, tolerance: 3.184e+09
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
for name,model in fitted_models.items():
    print(name,model.best_score_)
# Out:
# lasso 0.3015810788124356
# ridge 0.3098081478144799
# enet 0.33920226112500573

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
fitted_models['enet']
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('elasticnet',
#                                         ElasticNet(random_state=123))]),
#              n_jobs=-1,
#              param_grid={'elasticnet__alpha': [0.001, 0.005, 0.01, 0.05, 0.1,
#                                                0.5, 1, 5, 10],
#                          'elasticnet__l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]})

# %%
pred = fitted_models['enet'].predict(x_test)

# %%
print('r^2',r2_score(y_test,pred))
print('Mae',mean_absolute_error(y_test,pred))
# Out:
# r^2 0.402358583283166
# Mae 86683.7980936851

# %%
for name,model in fitted_models.items():
    pred=model.predict(x_test)
    print(name)
    print("------")
    print('r^2',r2_score(y_test,pred))
    print('Mae',mean_absolute_error(y_test,pred))
    print()
# Out:
# lasso
# ------
# r^2 0.40545563588248557
# Mae 85330.99925762744
#
# ridge
# ------
# r^2 0.4059782468929354
# Mae 85259.38862692291
#
# enet
# ------
# r^2 0.402358583283166
# Mae 86683.7980936851

# %%
type(fitted_models['enet'])
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
type(fitted_models['enet'].best_estimator_)
# Out:
# sklearn.pipeline.Pipeline

# %%
fitted_models['enet'].best_estimator_
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('elasticnet',
#                  ElasticNet(alpha=5, l1_ratio=0.9, random_state=123))])

# %%
import pickle

# %%
with open('final_model.kl','wb') as f:
    pickle.dump(fitted_models['enet'].best_estimator_,f)

# %%
df.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6d/6wf68xw50nn9jdmks7qx55f40000gn/T/ipykernel_10585/1890276076.py in <module>
# ----> 1 df.isnull()
#
# NameError: name 'df' is not defined
